# %% [markdown]
# Название проекта:
# Система способов оплаты
#
# Вариант задания:
# Вариант №16
#
# Описание проекта:
# Разработка системы различных способов оплаты на базе класса PaymentMethod.
# Система предусматривает онлайн-оплату, банковский перевод и оплату наличными.
