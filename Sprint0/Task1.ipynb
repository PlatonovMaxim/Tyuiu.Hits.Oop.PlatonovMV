# %% [markdown]
# 1. Классы и Объекты Задание:
# Ниже в блоке по примеру создайте класс Animal

# %%
// Создание класса
class Animal
{

}

// Основная программа
Animal MyAnimal = new Animal(); // Создание объекта

# %% [markdown]
# 2. Инкапсуляция Задание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте инкапсуляцию

# %%
// Создание класса
class Animal
{
    private string name; // Приватное поле

    public string Name // Свойство с геттером и сеттером
    {
        get { return name; }
        set { name = value; }
    }

    public void Eat() // Публичный метод
    {
        Console.WriteLine("Животное кушает...");
    }
}

// Основная программа
Animal MyAnimal = new Animal(); // Создание объекта
MyAnimal.Name = "Анфиса";
MyAnimal.Eat();
Console.WriteLine(MyAnimal.Name);
# Out:
# Животное кушает...
# Анфиса

# %% [markdown]
# 3. Наследование Задание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте наследование

# %%
class Animal
{
    private string name;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public void Move()
    {
        Console.WriteLine("Животное двигается...");
    }
}

class Dog : Animal
{
}

Animal myAnimal = new Animal();
Dog myDog = new Dog();

myDog.Name = "Бобик";
Console.WriteLine(myDog.Name);
myDog.Move();

myAnimal.Name = "Животное";
Console.WriteLine(myAnimal.Name);
myAnimal.Move();
# Out:
# Бобик
# Животное двигается...
# Животное
# Животное двигается...

# %% [markdown]
# 4. Полиморфизм Задание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте полиморфизм

# %%
class Animal
{
    public virtual void MakeSound()
    {
        Console.WriteLine("Животное издает звук");
    }
}

class Dog : Animal
{
    public override void MakeSound()
    {
        Console.WriteLine("Собака лает");
    }
}

Animal myAnimal = new Animal();
Dog myDog = new Dog();

myAnimal.MakeSound();
myDog.MakeSound();
# Out:
# Животное издает звук
# Собака лает

# %% [markdown]
# 5. Абстракция адание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте абстракцию

# %%
abstract class Animal
{
    public abstract void MakeSound();

    public void Move()
    {
        Console.WriteLine("Животное двигается...");
    }
}

class Dog : Animal
{
    public override void MakeSound()
    {
        Console.WriteLine("Собака лает...");
    }
}

Dog myDog = new Dog();

myDog.MakeSound();
myDog.Move();
# Out:
# Собака лает...
# Животное двигается...

# %% [markdown]
# 6. Ассоциация (Композиция и Агрегация) Задание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте композицию

# %%
class Heart
{
    public void Beat()
    {
        Console.WriteLine("Сердце бьется");
    }
}

class Animal
{
    private Heart heart;

    public Animal(Heart heart)
    {
        this.heart = heart;
    }

    public void Live()
    {
        heart.Beat();
        Console.WriteLine("Животное живет");
    }
}

Heart myHeart = new Heart();
Animal myAnimal = new Animal(myHeart);

myAnimal.Live();
# Out:
# Сердце бьется
# Животное живет

# %% [markdown]
# 7. Ассоциация (Композиция и Агрегация) Задание:
# Ниже в блоке по примеру создайте класс Animal и реализуйте агрегацию

# %%
abstract class LivingBeing
{
    public abstract void Live();
}

class Animal : LivingBeing
{
    private Owner owner;

    public Animal(Owner owner)
    {
        this.owner = owner;
    }

    public override void Live()
    {
        Console.WriteLine("Животное живет...");
    }
}

class Owner
{
    public string Name { get; set; }

    public Owner(string name)
    {
        Name = name;
    }

    public void Care(LivingBeing livingBeing)
    {
        Console.WriteLine($"{Name} заботится о животном...");
        livingBeing.Live();
    }
}

Owner maxim = new Owner("Максим");
Animal myAnimal = new Animal(maxim);

myAnimal.Live();
maxim.Care(myAnimal);
# Out:
# Животное живет...
# Максим заботится о животном...
# Животное живет...
